# %% [markdown]
# # 딥러닝의 필요한 도구

# %% [markdown]
# 2-2. 딥러닝을 위한 도구
# -Numpy : 파이썬 package중 하나

# %%
#python list
my_list = ['dahye','uijeong','jongwon']
print(my_list[1])
# Out:
# uijeong

# %%
#python 이중 list
my_list_2=[[1,2,3],[4,5,6]]
print(my_list_2[1,1:])
# Out:
# [5 6]

# %%
#배열의 크기가 커질수록 numpy 사용하는 것이 성능 good
import numpy as np
print(np.__version__)
# Out:
# 1.19.4

# %%
#numpy로 2차원 배열
my_arr=np.array([[1,2,3],[4,5,6,]])
print(my_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#numpy 배열인지 확인
type(my_arr) #코드 셀의 마지막 줄은 print 없이도 출력
# Out:
# numpy.ndarray

# %%
#numpy에서 element 선택 , python list와 동일
my_arr[1][1]
# Out:
# 5

# %%
#element의 sum
np.sum(my_arr)
# Out:
# 21

# %% [markdown]
# -Matplotlib : python의 표준 그래프 package

# %%
#선그래프
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5],[1,4,9,16,25])
#plt.plot([0,1,4,9,16]) #1,2,3,4,5가 y값이 되고 0부터 n-1까지 x값
#plt.plot([[1,2,5],[1,2,5],[1,2,5]])
#plt.plot([[1,0],[2,2],[3,4]]) 
plt.show()

# %%
#산점도
plt.scatter([1,2,3,4,5],[1,4,9,16,25])
plt.show()

# %%
#numpy 배열을 이용한 산점도
x=np.random.randn(1000)
y=np.random.randn(1000)
plt.scatter(x,y)
plt.show()
